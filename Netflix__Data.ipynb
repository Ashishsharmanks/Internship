# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # Load the Dataset

# %%
data=pd.read_csv("netflix_titles.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # Uniforming the headers in Uppercase

# %%
data.columns=data.columns.str.upper()

# %%
data.columns
# Out:
# Index(['SHOW_ID', 'TYPE', 'TITLE', 'DIRECTOR', 'CAST', 'COUNTRY', 'DATE_ADDED',
#        'RELEASE_YEAR', 'RATING', 'DURATION', 'LISTED_IN', 'DESCRIPTION'],
#       dtype='object')

# %% [markdown]
# # Renaming the Headers

# %%
data.rename(columns={"TYPE":"SHOW_TYPE"})
# Out:
#      SHOW_ID SHOW_TYPE                  TITLE         DIRECTOR  \
# 0         s1     Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2   TV Show          Blood & Water              NaN
# 2         s3   TV Show              Ganglands  Julien Leclercq
# 3         s4   TV Show  Jailbirds New Orleans              NaN
# 4         s5   TV Show           Kota Factory              NaN
# ...      ...       ...                    ...              ...
# 8802   s8803     Movie                 Zodiac    David Fincher
# 8803   s8804   TV Show            Zombie Dumb              NaN
# 8804   s8805     Movie             Zombieland  Ruben Fleischer
# 8805   s8806     Movie                   Zoom     Peter Hewitt
# 8806   s8807     Movie                 Zubaan      Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 0                                                   NaN  United States
# ...

# %%
data=data.rename(columns={"TYPE":"SHOW_TYPE"})

# %%
data
# Out:
#      SHOW_ID SHOW_TYPE                  TITLE         DIRECTOR  \
# 0         s1     Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2   TV Show          Blood & Water              NaN
# 2         s3   TV Show              Ganglands  Julien Leclercq
# 3         s4   TV Show  Jailbirds New Orleans              NaN
# 4         s5   TV Show           Kota Factory              NaN
# ...      ...       ...                    ...              ...
# 8802   s8803     Movie                 Zodiac    David Fincher
# 8803   s8804   TV Show            Zombie Dumb              NaN
# 8804   s8805     Movie             Zombieland  Ruben Fleischer
# 8805   s8806     Movie                   Zoom     Peter Hewitt
# 8806   s8807     Movie                 Zubaan      Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 0                                                   NaN  United States
# ...

# %% [markdown]
# # Checking for Null Values

# %%
data.isnull().sum()
# Out:
# SHOW_ID            0
# SHOW_TYPE          0
# TITLE              0
# DIRECTOR        2634
# CAST             825
# COUNTRY          831
# DATE_ADDED        10
# RELEASE_YEAR       0
# RATING             4
# DURATION           3
# LISTED_IN          0
# DESCRIPTION        0
# dtype: int64

# %% [markdown]
# # Replacing the Null Values with Unknown

# %%
data.fillna("Unknown")
# Out:
#      SHOW_ID SHOW_TYPE                  TITLE         DIRECTOR  \
# 0         s1     Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2   TV Show          Blood & Water          Unknown
# 2         s3   TV Show              Ganglands  Julien Leclercq
# 3         s4   TV Show  Jailbirds New Orleans          Unknown
# 4         s5   TV Show           Kota Factory          Unknown
# ...      ...       ...                    ...              ...
# 8802   s8803     Movie                 Zodiac    David Fincher
# 8803   s8804   TV Show            Zombie Dumb          Unknown
# 8804   s8805     Movie             Zombieland  Ruben Fleischer
# 8805   s8806     Movie                   Zoom     Peter Hewitt
# 8806   s8807     Movie                 Zubaan      Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 0                                               Unknown  United States
# ...

# %% [markdown]
# # Checking for Duplicate Values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Checking for Data Types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SHOW_ID       8807 non-null   object
#  1   SHOW_TYPE     8807 non-null   object
#  2   TITLE         8807 non-null   object
#  3   DIRECTOR      6173 non-null   object
#  4   CAST          7982 non-null   object
#  5   COUNTRY       7976 non-null   object
#  6   DATE_ADDED    8797 non-null   object
#  7   RELEASE_YEAR  8807 non-null   int64
#  8   RATING        8803 non-null   object
#  9   DURATION      8804 non-null   object
#  10  LISTED_IN     8807 non-null   object
#  11  DESCRIPTION   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Changing Date_Added Column Data Type to datetime

# %%
data["DATE_ADDED"] = pd.to_datetime(data["DATE_ADDED"], errors="coerce")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SHOW_ID       8807 non-null   object
#  1   SHOW_TYPE     8807 non-null   object
#  2   TITLE         8807 non-null   object
#  3   DIRECTOR      6173 non-null   object
#  4   CAST          7982 non-null   object
#  5   COUNTRY       7976 non-null   object
#  6   DATE_ADDED    8709 non-null   datetime64[ns]
#  7   RELEASE_YEAR  8807 non-null   int64
#  8   RATING        8803 non-null   object
#  9   DURATION      8804 non-null   object
#  10  LISTED_IN     8807 non-null   object
#  11  DESCRIPTION   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %% [markdown]
# # Changing Date Format to dd-mm-yy

# %%
data["DATE_ADDED"] = data["DATE_ADDED"].dt.strftime("%d-%m-%y")

# %%
data
# Out:
#      SHOW_ID SHOW_TYPE                  TITLE         DIRECTOR  \
# 0         s1     Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2   TV Show          Blood & Water              NaN
# 2         s3   TV Show              Ganglands  Julien Leclercq
# 3         s4   TV Show  Jailbirds New Orleans              NaN
# 4         s5   TV Show           Kota Factory              NaN
# ...      ...       ...                    ...              ...
# 8802   s8803     Movie                 Zodiac    David Fincher
# 8803   s8804   TV Show            Zombie Dumb              NaN
# 8804   s8805     Movie             Zombieland  Ruben Fleischer
# 8805   s8806     Movie                   Zoom     Peter Hewitt
# 8806   s8807     Movie                 Zubaan      Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 0                                                   NaN  United States
# ...
